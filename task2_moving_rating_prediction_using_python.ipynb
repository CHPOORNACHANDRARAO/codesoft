# %% [markdown]
# <a href="https://colab.research.google.com/github/CHPOORNACHANDRARAO/codesoft/blob/main/task2_moving_rating_prediction_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie=pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1') # Try reading the file with 'latin-1' encoding.
movie.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
movie.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
movie.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df_final=movie.dropna()

# %%
df_final.shape
# Out:
# (5659, 10)

# %%
df_final.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_final.drop_duplicates(inplace=True)
# Out:
# <ipython-input-44-c5009061c263>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop_duplicates(inplace=True)

# %%
df_final.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
df_final['Year']=df_final[Year].str.replace(r'\D','').astype(int)

# %%
sns.countplot(x='Genre',data=df_final)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.countplot(x='Director',hue='Rating',data=df_final)
# Out:
# <Axes: xlabel='Director', ylabel='count'>

# %%
df_final.Rating.plot.hist(bins=20,figsize=(12,6))
plt.ylabel('Rating')
plt.xlabel('Votes')
# Out:
# Text(0.5, 0, 'Votes')

# %%
df_final['Rating'].value_counts().plot(kind='bar',figsize=(12,6))
plt.show()

# %%
df_final['Rating'].value_counts().plot(kind='pie',figsize=(12,6))
plt.show()
